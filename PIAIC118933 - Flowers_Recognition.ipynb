# %% [markdown]
# Assignment: Flowers Recognition <br>
# Dataset Description:<br>
#
# This dataset contains 4242 images of flowers.<br>
# The data collection is based on the data flicr, google images, yandex images.<br>
# You can use this datastet to recognize plants from the photo.<br>
#
# Attribute Information:<br>
# The pictures are divided into five classes: chamomile, tulip, rose, sunflower, dandelion.<br>
# For each class there are about 800 photos. Photos are not high resolution, about 320x240 pixels. <br>
# <b>Also explore how to resize images in tensorflow and then resize all the images to a same size. </b> <br>
# This is a Multiclass Classification Problem.<br>

# %% [markdown]
# WORKFLOW : <br>
# Load Data <br>
# Split into 60 and 40 ratio.<br>
# Encode labels.<br>
# Create Model<br>
# Compilation Step (Note : Its a Multiclass Classification problem , select loss , metrics according to it)<br>
# Train the Model.<br>
# If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .<br>
# Prediction should be > 85%<br>
# Evaluation Step<br>
# Prediction<br>

# %% [markdown]
# Data : <br>
# https://drive.google.com/file/d/1-OX6wn5gA-bJpjPNfSyaYQLz-A-AB_uj/view?usp=sharing

# %%
import numpy as np
import pandas as pd
from matplotlib import image
import matplotlib.pyplot as plt
import glob

folders = glob.glob('flowers/*')

for folder in folders:
    labels = []
    for f in glob.glob(folder+'/*.jpg'): # as data containing JPG format
        labels.append(f)

read_images = []        
for img in labels:
    read_images.append(image.imread(img))


plt.imshow(read_images[0])
plt.show()

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.optimizers import *
from sklearn.model_selection import train_test_split

x = tf.convert_to_tensor(pd.DataFrame(np.ndarray(read_images)))

tf.image.rgb_to_grayscale(x) # converteing into gray scale
resized_images = tf.image.resize(x , (150, 150))
resized_images[0] # all the photo data cannot be displayed here so I am showing for one photo only
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-f15af9806ab7> in <module>
#       6 from sklearn.model_selection import train_test_split
#       7
# ----> 8 x = tf.convert_to_tensor(pd.Series(np.ndarray(read_images)))
#       9
#      10 tf.image.rgb_to_grayscale(x) # converteing into gray scale
#
# ValueError: maximum supported dimension for an ndarray is 32, found 984

# %%
# distribution into X and y & spliting data
from sklearn.model_selection import train_test_split
train_ratio = .6
test_ratio = .4

x_train, x_test, y_train, y_test = train_test_split(resized_images, labels, test_size = test_ratio) # as test size is 40%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-facf9446a5fb> in <module>
#       4 test_ratio = .4
#       5
# ----> 6 x_train, x_test, y_train, y_test = train_test_split(resized_images, labels, test_size = test_ratio) # as test size is 40%
#       7 x_train.shape, y_train.shape, x_test.shape, y_test.shape
#
# NameError: name 'resized_images' is not defined

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.optimizers import *


model = Sequential()
tf.keras.backend.set_floatx('float64')
model.add(tf.keras.layers.Dense(24, activation='relu'))
model.add(tf.keras.layers.Dense(1,))
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
model.fit(x_train, y_train, epochs=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-205442256c72> in <module>
#      11 model.add(tf.keras.layers.Dense(1,))
#      12 model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
# ---> 13 model.fit(x_train, y_train, epochs=200)
#
# NameError: name 'x_train' is not defined

# %%
# could not complete
# doing my best to complete
